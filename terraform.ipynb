# %%
import urllib.request
import requests
import json
import pandas as pd
from pandas import json_normalize
import subprocess

# %%
# feed_url = 'https://spot-price.s3.amazonaws.com/spot.js'
feed_url = 'https://spot-bid-advisor.s3.amazonaws.com/spot-advisor-data.json'
with requests.get(feed_url) as response:
    # data = json.loads(response.json())
    df = json_normalize(response.json())
    print(df.describe())
# Out:
#        instance_types.i4i.12xlarge.cores  instance_types.i4i.12xlarge.ram_gb  \
# count                                1.0                                 1.0
# mean                                48.0                               384.0
# std                                  NaN                                 NaN
# min                                 48.0                               384.0
# 25%                                 48.0                               384.0
# 50%                                 48.0                               384.0
# 75%                                 48.0                               384.0
# max                                 48.0                               384.0
#
#        instance_types.m6g.16xlarge.cores  instance_types.m6g.16xlarge.ram_gb  \
# count                                1.0                                 1.0
# mean                                64.0                               256.0
# std                                  NaN                                 NaN
# min                                 64.0                               256.0
# 25%                                 64.0                               256.0
# 50%                                 64.0                               256.0
# 75%                                 64.0                               256.0
# max                                 64.0                               256.0
#
#        instance_types.r5d.24xlarge.cores  instance_types.r5d.24xlarge.ram_gb  \
# count                                1.0                                 1.0
# mean                                96.0                               768.0
# std                                  NaN                                 NaN
# min                                 96.0                               768.0
# 25%                                 96.0                               768.0
# 50%                                 96.0                               768.0
# 75%                                 96.0                               768.0
# max                                 96.0                               768.0
#
#        instance_types.c6g.xlarge.cores  instance_types.c6g.xlarge.ram_gb  \
# count                              1.0                               1.0
# mean                               4.0                               8.0
# std                                NaN                               NaN
# min                                4.0                               8.0
# 25%                                4.0                               8.0
# 50%                                4.0                               8.0
# 75%                                4.0                               8.0
# max                                4.0                               8.0
#
#        instance_types.c5d.18xlarge.cores  instance_types.c5d.18xlarge.ram_gb  \
# count                                1.0                                 1.0
# mean                                72.0                               144.0
# std                                  NaN                                 NaN
# min                                 72.0                               144.0
# 25%                                 72.0                               144.0
# 50%                                 72.0                               144.0
# 75%                                 72.0                               144.0
# max                                 72.0                               144.0
#
#        ...  spot_advisor.ap-southeast-2.Windows.p3.2xlarge.s  \
# count  ...                                               1.0
# mean   ...                                              83.0
# std    ...                                               NaN
# min    ...                                              83.0
# 25%    ...                                              83.0
# 50%    ...                                              83.0
# 75%    ...                                              83.0
# max    ...                                              83.0
#
#        spot_advisor.ap-southeast-2.Windows.p3.2xlarge.r  \
# count                                               1.0
# mean                                                4.0
# std                                                 NaN
# min                                                 4.0
# 25%                                                 4.0
# 50%                                                 4.0
# 75%                                                 4.0
# max                                                 4.0
#
#        spot_advisor.ap-southeast-2.Windows.c5d.2xlarge.s  \
# count                                                1.0
# mean                                                51.0
# std                                                  NaN
# min                                                 51.0
# 25%                                                 51.0
# 50%                                                 51.0
# 75%                                                 51.0
# max                                                 51.0
#
#        spot_advisor.ap-southeast-2.Windows.c5d.2xlarge.r  \
# count                                                1.0
# mean                                                 4.0
# std                                                  NaN
# min                                                  4.0
# 25%                                                  4.0
# 50%                                                  4.0
# 75%                                                  4.0
# max                                                  4.0
#
#        spot_advisor.ap-southeast-2.Windows.i3en.12xlarge.s  \
# count                                                1.0
# mean                                                66.0
# std                                                  NaN
# min                                                 66.0
# 25%                                                 66.0
# 50%                                                 66.0
# 75%                                                 66.0
# max                                                 66.0
#
#        spot_advisor.ap-southeast-2.Windows.i3en.12xlarge.r  \
# count                                                1.0
# mean                                                 0.0
# std                                                  NaN
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        spot_advisor.ap-southeast-2.Windows.i4i.4xlarge.s  \
# count                                                1.0
# mean                                                61.0
# std                                                  NaN
# min                                                 61.0
# 25%                                                 61.0
# 50%                                                 61.0
# 75%                                                 61.0
# max                                                 61.0
#
#        spot_advisor.ap-southeast-2.Windows.i4i.4xlarge.r  \
# count                                                1.0
# mean                                                 1.0
# std                                                  NaN
# min                                                  1.0
# 25%                                                  1.0
# 50%                                                  1.0
# 75%                                                  1.0
# max                                                  1.0
#
#        spot_advisor.ap-southeast-2.Windows.m6id.24xlarge.s  \
# count                                                1.0
# mean                                                49.0
# std                                                  NaN
# min                                                 49.0
# 25%                                                 49.0
# 50%                                                 49.0
# 75%                                                 49.0
# max                                                 49.0
#
#        spot_advisor.ap-southeast-2.Windows.m6id.24xlarge.r
# count                                                1.0
# mean                                                 4.0
# std                                                  NaN
# min                                                  4.0
# 25%                                                  4.0
# 50%                                                  4.0
# 75%                                                  4.0
# max                                                  4.0
#
# [8 rows x 41040 columns]

# %%
from python_terraform import *

# %%
tf = Terraform(working_dir='./crawl_infrastructure')
for workspace in ["nv", "oregon", "ohio", "nc"]:
    tf.set_workspace(workspace)
    tf.apply(skip_plan=True)

# %%
tf = Terraform(working_dir='./crawl_infrastructure')
for workspace in ["nv", "oregon", "ohio", "nc"]:
    tf.set_workspace(workspace)
    tf.destroy(skip_plan=True)
